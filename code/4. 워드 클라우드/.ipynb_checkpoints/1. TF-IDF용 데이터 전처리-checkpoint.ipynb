# %%
import pandas as pd

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

path = '/Users/sonjiyeong/Documents/랩실 프로젝트/스마트폰 리뷰마이닝/2. 속성 기반 감성 분석/output/'

# %%
df_p = pd.read_csv(path+'최종_period_데이터프레임.csv')[['id', 'period']]

# %%
data = pd.read_csv(path + '감성분석결과_atepc_병합')
df = data.copy()

# %%
# 두개 모델 갑성 전처리
df['f_sentiment'] = df.apply(lambda row: row['sentiment'] if pd.isna(row['bf_sentiment']) else row['bf_sentiment'], axis=1)
print('제거 전 데이터 개수:', df.shape[0])
df = df[~((df['feature'] == 'charg') & df['bf_aspect'].isna())] # atepc charge 뽑힌거 아닌거는 다 제외하기 
df = df[df['main_feature']!='other'] # other(분류한 속성이 아닌 것) 제거하기 
print('제거 후 데이터 개수:', df.shape[0])
# Out:
# 제거 전 데이터 개수: 103046
# 제거 후 데이터 개수: 96081

# %%
df_sel = df[['id', 'model', 'ori_feature', 'f_sentiment']]
df_sel.head()
# Out:
#    id      model        ori_feature f_sentiment
# 0   1  galaxy_s3  quality materials    Negative
# 1   2  galaxy_s3             memory     Neutral
# 2   2  galaxy_s3            battery    Positive
# 3   2  galaxy_s3       battery life    Positive
# 4   3  galaxy_s3               16gb    Negative

# %%
df_asp = pd.read_csv(path + 'apc_훈련데이터셋.csv')
df = pd.merge(df_asp, df_sel, on=['id', 'ori_feature'], how='right')

# %%
# 리뷰 등장 문장 전처리
df['mark_sentence'] = df['mark_sentence'].replace('?', '.').replace('!', '.')
df['mark_sentence'] = df['mark_sentence'].apply(lambda x: x.split('.'))

# %%
def sentence_select(mark_sentence):
    for sen in mark_sentence:
        if '[B-ASP]' in sen:
            new_sen = sen.replace('[B-ASP]', '').replace('[E-ASP]', '')
            return new_sen

# %%
df['sentence'] = df['mark_sentence'].apply(sentence_select)
df = df[['id', 'model', 'sentence', 'ori_feature', 'feature', 'main_feature', 'f_sentiment']]

# %%
data = df.copy()
data.head()
data.shape
# Out:
#    id      model                                           sentence  \
# 0   1  galaxy_s3   not at all sure why samsung ' s best mobile t...
# 1   2  galaxy_s3   i like the fact to expand memory by micro sd ...
# 2   2  galaxy_s3   i like the fact to expand memory by micro sd ...
# 3   2  galaxy_s3   battery life is great for me so far looking f...
# 4   3  galaxy_s3   however the expensive galaxy s3 only has 16gb...
#
#          ori_feature         feature main_feature f_sentiment
# 0  quality materials  qualiti_materi         body    Negative
# 1             memory          memori         stor     Neutral
# 2            battery         batteri          bat    Positive
# 3       battery life    batteri_life          bat    Positive
# 4               16gb            16gb         stor    Negative
# (148067, 7)

# %%
data = pd.merge(data, df_p[df_p['period']<4], on='id')
data
# Out:
#            id        model                                           sentence  \
# 0           1    galaxy_s3   not at all sure why samsung ' s best mobile t...
# 1           2    galaxy_s3   i like the fact to expand memory by micro sd ...
# 2           2    galaxy_s3   i like the fact to expand memory by micro sd ...
# 3           2    galaxy_s3   battery life is great for me so far looking f...
# 4           3    galaxy_s3   however the expensive galaxy s3 only has 16gb...
# ...       ...          ...                                                ...
# 113872  76227  galaxy_s10e   i loved my s10 + , but the size and curved gl...
# 113873  76227  galaxy_s10e   the s10e is a powerhouse of a smartphone and ...
# 113874  76227  galaxy_s10e   the s10e is a powerhouse of a smartphone and ...
# 113875  76227  galaxy_s10e   the s10e is a powerhouse of a smartphone and ...
# 113876  76227  galaxy_s10e   it ' s a delight to hold and operate for exte...
#
#               ori_feature         feature main_feature f_sentiment  period
# 0       quality materials  qualiti_materi         body    Negative       1
# 1                  memory          memori         stor     Neutral       1
# 2                 battery         batteri          bat    Positive       1
# 3            battery life    batteri_life          bat    Positive       1
# 4                    16gb            16gb         stor    Negative       1
# ...                   ...             ...          ...         ...     ...
# 113872       glass screen    glass_screen          dis    Positive       3
# 113873              sized            size         body    Positive       3
# 113874        form factor     form_factor         body    Positive       3
# 113875             screen          screen          dis    Positive       3
# 113876              sizes            size         body    Negative       3
#
# [113877 rows x 8 columns]

# %%
data.to_csv('tf-idf용_데이터프레임.csv', index=False)
